# %% [markdown]
# <a href="https://colab.research.google.com/github/lais654/Aula-String/blob/main/String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Teste Lower

# %%
nome = "Ana"
print (nome.lower())
# Out:
# ana

# %% [markdown]
# Teste Upper

# %%
nome = "Ana"
print (nome.upper())
# Out:
# ANA

# %% [markdown]
# Teste Strip

# %%
nome = "Ana"
print (nome.strip())
# Out:
# Ana

# %% [markdown]
# Teste Replace (substituição)

# %%
texto = "Olá João"
print (texto.replace("João", "Maria"))
# Out:
# Olá Maria

# %% [markdown]
# Teste Len

# %%
nome = "Maria"
print (len(nome))
# Out:
# 5

# %% [markdown]
# Acesso

# %%
nome = "Maria"
print (nome[0])#
print (nome[1])#
print (nome[2])#
print (nome[3])#
print (nome[4])#
# Out:
# M
# a
# r
# i
# a

# %%
nome = "Maria"
nome = nome.replace("M", "N")

print (nome[0])#
print (nome[1])#
print (nome[2])#
print (nome[3])#
print (nome[4])#
# Out:
# N
# a
# r
# i
# a

# %%
nome = "Maria"
print (nome[0:3]) # mar
print (nome[2:] )# ia
# Out:
# Mar
# ria

# %% [markdown]
# Exemplo prático

# %%
cpf = "123.456.789-00"
cpf = cpf.replace(".", "")

print (cpf[0])#
print (cpf[1])#
print (cpf[2])#
print (cpf[3])#
print (cpf[4])#
print (cpf[5])#
print (cpf[6])#
print (cpf[7])#
print (cpf[8])#
print (cpf[9])#
print (cpf[9])#
print (cpf[10])#
print (cpf[11])#
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# -
# -
# 0
# 0

# %% [markdown]
# Atividade 1

# %%
nome = " MARIA EDUARDA ALMEIDA "
email = " MARIA.ALMEIDA@EMPRESA.COM "

print (nome.strip())
print (email.strip())
print (nome.lower())
print (email.lower())
print (email.replace ("@EMPRESA.COM", "@gmail.com"))
print (len(nome))
print (nome[1])#
print (nome[21])#
# Out:
# MARIA EDUARDA ALMEIDA
# MARIA.ALMEIDA@EMPRESA.COM
#  maria eduarda almeida
#  maria.almeida@empresa.com
#  MARIA.ALMEIDA@gmail.com
# 23
# M
# A

# %% [markdown]
# Atividade 2

# %%
produto = " NOTEBOOK DELL INSPIRON "
categoria = " INFORMÁTICA "
codigo = " ABC-123-XYZ "

print (produto.strip())
print (categoria.strip())
print (codigo.strip())
print (categoria.lower())
print (codigo.replace("-", ""))
print (len(produto))
print (produto[1])#
print (codigo[1])#
print (codigo[2])#
print (codigo[3])#
print (codigo[5])#
# Out:
# NOTEBOOK DELL INSPIRON
# INFORMÁTICA
# ABC-123-XYZ
#  informática
#  ABC123XYZ
# 24
# N
# A
# B
# C
# 1
